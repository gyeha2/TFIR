# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import pandas as pd
df = pd.read_csv('./gdrive/My Drive/Colab Notebooks/labeled_alpha.csv')

#unfeature = pd.merge(one, two, on='actor_account', how='outer')
#train = pd.merge(unfeature, three, on='actor_account', how='outer')

#unfeature2 = pd.merge(four, five, on='actor_account', how='outer')
#test = pd.merge(unfeature2, six, on='actor_account', how='outer')

# %%
model_data= df.copy()
model_data.head()
# Out:
#    actor_account  login_count  ...  playtime_per_quest  class
# 0        1000127         10.0  ...         4779.538462      0
# 1        1000344         17.0  ...         5411.647059      0
# 2        1000779         11.0  ...            0.000000      1
# 3        1000949          8.0  ...            0.000000      1
# 4        1001067         20.0  ...         1204.199566      0
#
# [5 rows x 25 columns]

# %%
model_data.fillna(model_data.mean(), inplace=True)
x = model_data.iloc[:, :-1]
y = model_data.iloc[:, -1]

# %%
from sklearn.model_selection import train_test_split
print(list(y).count(0))
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3)
# Out:
# 5000

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
k_fold = KFold(n_splits=10, shuffle=True, random_state=0)

# %%
from sklearn.ensemble import RandomForestClassifier
model_data.fillna(model_data.mean(), inplace=True)
x = model_data.iloc[:, :-1]
y = model_data.iloc[:, -1]
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3)
rnd_clf = RandomForestClassifier()
rnd_clf.fit(x_train, y_train)
y_pred_rf = rnd_clf.predict(x_test)
model_data.shape
# Out:
# (5400, 25)

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred_rf, target_names=['Human', 'Bot']))
# Out:
#               precision    recall  f1-score   support
#
#        Human       0.99      1.00      0.99      1508
#          Bot       0.94      0.85      0.89       112
#
#     accuracy                           0.99      1620
#    macro avg       0.96      0.92      0.94      1620
# weighted avg       0.99      0.99      0.99      1620

# %%
from sklearn.tree import DecisionTreeClassifier
model_data.fillna(model_data.mean(), inplace=True)
x = model_data.iloc[:, :-1]
y = model_data.iloc[:, -1]
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3)
rnd_clf = DecisionTreeClassifier()
rnd_clf.fit(x_train, y_train)
y_pred_rf = rnd_clf.predict(x_test)

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred_rf, target_names=['Human', 'Bot']))
# Out:
#               precision    recall  f1-score   support
#
#        Human       0.99      0.98      0.98      1506
#          Bot       0.78      0.82      0.80       114
#
#     accuracy                           0.97      1620
#    macro avg       0.88      0.90      0.89      1620
# weighted avg       0.97      0.97      0.97      1620

# %%
from sklearn.naive_bayes import GaussianNB
model_data.fillna(model_data.mean(), inplace=True)
x = model_data.iloc[:, :-1]
y = model_data.iloc[:, -1]
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3)
rnd_clf = GaussianNB()
rnd_clf.fit(x_train, y_train)
y_pred_rf = rnd_clf.predict(x_test)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred_rf, target_names=['Human', 'Bot']))
# Out:
#               precision    recall  f1-score   support
#
#        Human       0.97      0.95      0.96      1505
#          Bot       0.52      0.68      0.59       115
#
#     accuracy                           0.93      1620
#    macro avg       0.75      0.82      0.78      1620
# weighted avg       0.94      0.93      0.94      1620

# %%
from sklearn.svm import SVC
model_data.fillna(model_data.mean(), inplace=True)
x = model_data.iloc[:, :-1]
y = model_data.iloc[:, -1]
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3)
rnd_clf = SVC()
rnd_clf.fit(x_train, y_train)
y_pred_rf = rnd_clf.predict(x_test)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred_rf, target_names=['Human', 'Bot']))
# Out:
#               precision    recall  f1-score   support
#
#        Human       0.93      1.00      0.96      1497
#          Bot       1.00      0.02      0.03       123
#
#     accuracy                           0.93      1620
#    macro avg       0.96      0.51      0.50      1620
# weighted avg       0.93      0.93      0.89      1620
